# %%
import pandas as pd

# %%
#Open the CSV file using a data analysis tool like Pandas in Python
df=pd.read_csv("/Users/new/Downloads/archive (1)/ecommerce_sales_data.csv")
#Display the first few rows to get an overview of the dataset structure.

print(df.head())
# Out:
#                                Order ID Product Name       Category   Price  \
# 0  261e3740-c0e9-42b1-bf87-881ac950fa3a     audience  Home & Garden  766.85
# 1  0b332b34-46dc-4eaf-a808-fec7e97ffbc6         such       Clothing  331.42
# 2  432e0b36-724d-4521-85ae-f66db8af8105         read       Clothing  708.10
# 3  ca20fb08-5c65-43b8-9577-3fa49913f93b        skill    Electronics  774.09
# 4  1dce189c-8c60-455f-a6f2-69bb2cb71539         cold    Electronics  397.22
#
#    Quantity  Total Sales                           Customer ID  Customer Age  \
# 0         4      3067.40  81af1248-afff-46ee-a091-81cf33d0d957            39
# 1         4      1325.68  f3f3f4ac-7ad0-4362-9134-383096d16ac8            21
# 2        10      7081.00  c4fc4269-3c1d-4b6b-ad23-d437c328d63f            27
# 3         2      1548.18  578e2d1a-d92a-449d-8eeb-b704110b2975            51
# 4         1       397.22  dc6ed196-0874-46bd-bbb9-c5534f619349            45
#
#   Customer Gender Purchase Date Purchase Time
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 11 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Order ID         100000 non-null  object
#  1   Product Name     100000 non-null  object
#  2   Category         100000 non-null  object
#  3   Price            100000 non-null  float64
#  4   Quantity         100000 non-null  int64
#  5   Total Sales      100000 non-null  float64
#  6   Customer ID      100000 non-null  object
#  7   Customer Age     100000 non-null  int64
#  8   Customer Gender  100000 non-null  object
#  9   Purchase Date    100000 non-null  object
#  10  Purchase Time    100000 non-null  object
# dtypes: float64(2), int64(2), object(7)
# memory usage: 8.4+ MB

# %%
#Check the total number of rows and columns to understand dataset size.
print(df.shape)
# Out:
# (100000, 11)

# %%
#Identify different data types
print(df.dtypes)
# Out:
# Order ID            object
# Product Name        object
# Category            object
# Price              float64
# Quantity             int64
# Total Sales        float64
# Customer ID         object
# Customer Age         int64
# Customer Gender     object
# Purchase Date       object
# Purchase Time       object
# dtype: object

# %%
#Examine if key fields like Order Date, Revenue, and Customer ID are present.
imp_col=["Purchase Date","Customer ID","Price"]
print(["Yes important column is present" if i in df.columns else "imp column missing" for i in imp_col])
# Out:
# ['Yes important column is present', 'Yes important column is present', 'Yes important column is present']

# %%
#Scan the dataset for missing or null values in important columns.
missing_val=df.isnull().sum()
print(missing_val)
# Out:
# Order ID           0
# Product Name       0
# Category           0
# Price              0
# Quantity           0
# Total Sales        0
# Customer ID        0
# Customer Age       0
# Customer Gender    0
# Purchase Date      0
# Purchase Time      0
# dtype: int64

# %%
#Identify duplicate transactions that may impact the accuracy of analysis.
dupli=df.duplicated().sum()
print(dupli)
# Out:
# 0

# %%
#duplicates in rows
dup_rows = df [df.duplicated()]
print(dup_rows.head())
# Out:
# Empty DataFrame
# Columns: [Order ID, Product Name, Category, Price, Quantity, Total Sales, Customer ID, Customer Age, Customer Gender, Purchase Date, Purchase Time]
# Index: []

# %%
#Note down any inconsistencies in formatting
invalid_dates = df["Purchase Date"].isna().sum()
print("Invalid date entries:", invalid_dates)
# Out:
# Invalid date entries: 0

# %%
#Focus on sales and revenue-related columns that will be used in trend analysis.
sale_cols=["Purchase Date", "Price", "Quantity"]
df[sale_cols].head()
# Out:
#   Purchase Date   Price  Quantity
# 0    25/05/2024  766.85         4
# 1    04/05/2024  331.42         4
# 2    07/05/2024  708.10        10
# 3    23/05/2024  774.09         2
# 4    15/03/2024  397.22         1

# %%
#Look for customer segmentation features like purchase frequency and spending behavior.
customer_spending=df.groupby("Customer ID")["Price"].sum()
customer_order=df.groupby("Customer ID")["Order ID"].count()

# %%
df.to_csv("cleaned_ecommerce_data.csv", index=False)

# %%
duplicates = df.duplicated(subset=["Order ID", "Customer ID"]).sum()
print("Duplicate rows:", duplicates)
# Out:
# Duplicate rows: 0

# %%
df["Price"] = pd.to_numeric(df["Price"], errors="coerce")
df["Quantity"] = pd.to_numeric(df["Quantity"], errors="coerce")

# %%
df["Category"] = df["Category"].str.strip().str.lower()

# %%
Q1 = df["Revenue"].quantile(0.25)
Q3 = df["Revenue"].quantile(0.75)
IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

outliers = df[(df["Revenue"] < lower) | (df["Revenue"] > upper)]
print(outliers)
# Out:
# Empty DataFrame
# Columns: [Order ID, Product Name, Category, Price, Quantity, Total Sales, Customer ID, Customer Age, Customer Gender, Purchase Date, Purchase Time, Revenue]
# Index: []

# %%
df.to_csv("/Users/new/Downloads/istudio/ecommercecleaned_ecommerce_dataset.csv", index=False)
